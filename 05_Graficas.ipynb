# %% [markdown]
# <a href="https://colab.research.google.com/github/jcjimenezb123/ProgramacionPython/blob/master/05_Graficas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(-5,5)
y=np.sin(x)

plt.plot(x,y)
plt.grid(linestyle='-.')
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-bright')
plt.grid(linestyle='--')
plt.plot(x,y)
plt.show()

# %%
x=np.linspace(-2,2)
y=np.exp(x**2)-30
plt.plot(x,y)
plt.title('Titulo de la grafica $f(x)=e^{x^2}-30$',fontsize=20)
plt.xlabel('x $[cm^2]$')
plt.ylabel('y $[m/s^2]$')
plt.show()

# %%
x=np.linspace(-2,2)
y=np.exp(x**2)-30
plt.plot(x,y)
plt.xlim(0,3)
plt.ylim(-40,40)
plt.show()

# %%
x=np.linspace(-2,2)
y=np.exp(x**2)-30
plt.plot(x,y)
plt.xticks(ticks=[-2,-1,1,2],labels=['- dos','- uno','uno','dos'],rotation=45,color='b')
plt.yticks(ticks=[-30,0,30],labels=['Bajo','Medio','Alto'],rotation=45,color='y')
plt.ylim(-40,40)
plt.show()

# %%
x=np.linspace(-2,2)
y=np.cos(x)*np.exp(x)
plt.plot(x,y,'-.',c=(1,0,0),lw=3)
plt.show()

# %%
t = np.linspace(0,2*np.pi,100)

x = 16*np.sin(t)**3
y = 13*np.cos(t) - 5*np.cos(2*t) - 2*np.cos(3*t) - np.cos(4*t)

# Plot line with RGB tuple (red=1, green=0.2, blue=0.5)
# and 20pt line width
plt.plot(x,y,c=(1,0.2,0.5),lw=20)

# Add features to our figure
plt.text(0,0,'I love Python',horizontalalignment='center',fontsize=28,color='c')
plt.axis('equal')
plt.axis('off')

plt.show()

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Create just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')

# Create two subplots and unpack the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# Create four polar axes and access them through the returned array
fig, axs = plt.subplots(2, 2)
axs[0, 0].hist(np.random.randn(100),bins=20)
axs[0, 1].plot(np.random.randn(50).cumsum(),'k--')
axs[1, 0].pie(np.random.randn(10))
axs[1, 1].scatter(np.arange(30),np.arange(30)+3*np.random.randn(30))

plt.show()

# %%
# Create some mock data
t = np.arange(0.01, 10.0, 0.01)
data1 = np.exp(t)
data2 = np.sin(2 * np.pi * t)

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('exp', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('sin', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
x=np.linspace(-10,30,200)
y=np.pi*x**2*(30-x)/3-1000

fig, ax = plt.subplots()

lados=['top','right','bottom','left']
for lado in lados:
  ax.spines[lado].set_position('zero')
  ax.spines[lado].set_color('y')

plt.plot(x,y,lw=2)
plt.fill_between(x,y,where=(x>=10)&(x<=25),color='c' )
plt.text(12,1000,'$\int_a^bf(x)dx$',color='w',fontsize=20)
plt.grid(linestyle='--')
plt.show()

# %%
x=np.linspace(0,5,100)
y1=x**2-5
y2=10*np.sin(x)

fig, ax = plt.subplots()

lados=['top','right','bottom','left']
for lado in lados:
  ax.spines[lado].set_position('zero')
  ax.spines[lado].set_color('y')

plt.plot(x,y1,x,y2)
plt.fill_between(x,y1,y2,where=(x>=3)&(x<=4.5),color='c')
plt.grid(linestyle='--')
plt.show()

# %%
x = np.linspace(0, 10, 11)
y = [3.9, 4.4, 10.8, 10.3, 11.2, 13.1, 14.1,  9.9, 13.9, 15.1, 12.5]

# fit a linear curve an estimate its y-values and their error.
a, b = np.polyfit(x, y, deg=1)
y_est = a * x + b
y_err = x.std() * np.sqrt(1/len(x) +
                          (x - x.mean())**2 / np.sum((x - x.mean())**2))

fig, ax = plt.subplots()
ax.plot(x, y, 'o', color='tab:green')
ax.set_ylim(0,18)
fig.savefig('1.png')

ax.plot(x, y_est, '-.')
ax.set_ylim(0,18)
fig.savefig('2.png')

ax.fill_between(x, y_est - y_err, y_est + y_err, alpha=0.2)
ax.set_ylim(0,18)
fig.savefig('3.png')

plt.show()

# %%
x=np.linspace(-5,5,100)
y=np.cos(x)*np.exp(x)

fig, ax = plt.subplots(figsize=(14, 6))
#plt.style.use('seaborn-notebook')
plt.plot(x,y)
ax.annotate("Inicio", xy=(x[0],y[0]),  xycoords='data',
            xytext=(-3, -20), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=-0.2"))
ax.annotate("Cero", xy=(0, 1),  xycoords='data',
            bbox=dict(boxstyle="round4", fc="none", ec="gray"),
            xytext=(1, 10), textcoords='data', ha='center',
            arrowprops=dict(arrowstyle="->"))
ax.annotate('Periodo caida', xy=(1, 1), xycoords='data', ha='center',
            xytext=(3, 2), textcoords='data')
ax.annotate('', xy=(1, 1), xytext=(4, 1),
            xycoords='data', textcoords='data',
            arrowprops={'arrowstyle': '|-|,widthA=0.2,widthB=0.2', })
ax.annotate('Minimo', xy=(4, -35),  xycoords='data',
            xytext=(2.5, -10), textcoords='data',
            arrowprops=dict(arrowstyle="fancy",
                            fc="0.6", ec="none",
                            connectionstyle="angle3,angleA=0,angleB=-90"))

ax.annotate('subida', xy=(4.5, -20),  xycoords='data',
            xytext=(5, -30), textcoords='data',
            bbox=dict(boxstyle="round4,pad=.5", fc="0.9"),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle,angleA=0,angleB=-80,rad=20"))
ax.annotate('Maximo', xy=(5, 40),  xycoords='data',
             xytext=(4, 30), textcoords='data',
             size=13, ha='right', va="center",
             bbox=dict(boxstyle="round", alpha=0.1),
             arrowprops=dict(arrowstyle="wedge,tail_width=0.5", alpha=0.1));

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return np.cos(x)+np.sin(3*x)

x=np.linspace(0,5)
y=f(x)
fig=plt.figure(figsize=(14,6))
ax=plt.gca()
plt.plot(x,y,linewidth=2)
plt.grid(linestyle='--', linewidth=0.9, alpha=0.35)
plt.axvspan(xmin=1, xmax=2, facecolor='g', alpha=0.1)
plt.axhspan(ymin=f(1), ymax=f(2), facecolor='b', alpha=0.1)
plt.axhline(f(3.6),0,5,linestyle='-.',color='r')
plt.axvline(3.6,f(3.6),2,linestyle='--',color='m')
plt.show()

# %%
plt.figure(figsize=(10,7), dpi=80)
x = np.linspace(0, 2*np.pi, 1000)
sine = plt.plot(x,np.sin(x))
cosine = plt.plot(x,np.cos(2*x))
sine_2 = plt.plot(x,np.sin(x+.5))
cosine_2 = plt.plot(x,np.cos(x+.5))
plt.gca().set(ylim=(-1.25, 1.5), xlim=(-.5, 7))
plt.title('Ejemplo de leyendas', fontsize=18)

# Modify legend
plt.legend([sine[0], cosine[0], sine_2[0], cosine_2[0]],   # plot items
           ['sin(x)', 'cos(2x)', 'sin(x+0.5)', 'cos(x+0.5)'],  
           frameon=True,                                   # legend border
           framealpha=1,                                   # transparency of border
           ncol=2,                                         # num columns
           shadow=True,                                    # shadow on
           borderpad=1,                                    # thickness of border
           title='Senos y Cosenos',                        # title
           loc='best')                                     # localizacion
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
x = np.linspace(-0.50, 1., 1000)

# Outer Plot
ax.plot(x, x**2)
ax.plot(x, np.sin(x))
ax.set(xlim=(-0.5, 1.0), ylim=(-0.5,1.2))
fig.tight_layout()
plt.grid(linestyle='--')

# Inner Plot
inner_ax = fig.add_axes([0.2, 0.55, 0.35, 0.35]) # x, y, width, height
inner_ax.plot(x, x**2,'--')
inner_ax.plot(x, np.sin(x),'-.')
inner_ax.set(title='Acercamiento', xlim=(0.87,0.88),ylim=(0.75,0.78))
inner_ax.grid(linestyle='--')
ax.set_title("Grafica principal", fontsize=20)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
x=np.linspace(1,5)
axes[0].plot( x, np.exp(x))
axes[0].plot(x,x**4)
axes[0].set_title("Escala normal")
axes[1].plot (x, np.exp(x))
axes[1].plot(x, x**4)
axes[1].set_yscale("log")
axes[1].set_title("Escala logaritmica (y)")
axes[0].set_xlabel("x axis")
axes[0].set_ylabel("y axis")
axes[0].xaxis.labelpad = 10
axes[1].set_xlabel("x axis")
axes[1].set_ylabel("y axis")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.random.rand(100)
y=np.random.rand(100)

# Plot
figure, axes = plt.figure(), plt.gca()
plt.scatter(x,y,c='blue', edgecolors='yellow')
circulo=plt.Circle((0.3,0.6),0.2,alpha=0.3,color='magenta')
axes.add_patch(circulo)
plt.show()

# %%
x = np.random.randn(100)
y = np.random.randn(100)
colors = np.random.rand(100)
sizes = 100 * np.random.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='viridis')
plt.colorbar()
plt.show()

# %%
# Scatterplot with varying size and color of points
import pandas as pd
midwest = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/midwest_filter.csv")

# Plot
fig = plt.figure(figsize=(14, 7), dpi= 80, facecolor='w', edgecolor='k')    
plt.scatter('area', 'poptotal', data=midwest, s='dot_size', c='popdensity', cmap='Reds', edgecolors='red', linewidths=.5)
plt.title("Bubble Plot of PopTotal vs Area\n(color: 'popdensity' & size: 'dot_size' - both are numeric columns in midwest)", fontsize=16)
plt.xlabel('Area', fontsize=18)
plt.ylabel('Poptotal', fontsize=18)
plt.colorbar()
plt.show()

# %%
# Generate normal distributed sample points in 2-D
x, y = np.random.multivariate_normal([0, 0], [[1, 1], [1, 2]], 3000).T
# Define subplot styles
fig = plt.figure(figsize=(10, 10))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
ax = fig.add_subplot(grid[:-1, 1:])
ax_x = fig.add_subplot(grid[-1, 1:])
ax_y = fig.add_subplot(grid[:-1, 0])
# Plot the data to subplots
ax.scatter(x, y, s=5, alpha=0.5)
ax_x.hist(x, 60, orientation='vertical')
ax_y.hist(y, 60, orientation='horizontal')
ax_x.invert_yaxis()
ax_y.invert_xaxis()
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
fig,ax = plt.subplots()
ax.axis('equal')
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
ax.pie(students,
       explode=(0,0,0.1,0.1,0), 
       labels = langs,autopct='%1.2f%%',
       shadow=True)
plt.show()

# %%
fig,ax = plt.subplots()
ax.axis('equal')
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
ax.pie(students,
       labels = langs,autopct='%1.2f%%',
       startangle=90,
       shadow=True)
#draw circle
centre_circle = plt.Circle((0,0),0.75,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax.axis('equal')  
plt.tight_layout()
plt.show()

# %%
# Data to plot
labels = ['Python', 'C++', 'Ruby', 'Java']
sizes = [504, 337, 415, 280]
labels_gender = ['Man','Woman','Man','Woman','Man','Woman','Man','Woman']
sizes_gender = [315,189,125,212,270,145,190,90]
colors = ['#ff6666', '#ffcc99', '#99ff99', '#66b3ff']
colors_gender = ['#c2c2f0','#ffb3e6', '#c2c2f0','#ffb3e6', '#c2c2f0','#ffb3e6', '#c2c2f0','#ffb3e6']
 
# Plot
with plt.xkcd():
    plt.pie(sizes, labels=labels, colors=colors, startangle=90,frame=True)
    plt.pie(sizes_gender,labels=labels_gender,colors=colors_gender,radius=0.75,startangle=90)
    centre_circle = plt.Circle((0,0),0.5,color='black', fc='white',linewidth=0)
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)
    
    plt.axis('equal')
    plt.tight_layout()
    plt.show()

# %%
fig.savefig('migrafica.png')

# %%
fig.savefig('migrafica2.png',transparent=True)

# %%
fig.savefig('migrafica.pdf')

# %%
import imageio

# Crear un GIF
with imageio.get_writer('mygif.gif', mode='I', fps=1) as writer:
    for filename in ['1.png', '2.png', '3.png']:
        image = imageio.imread(filename)
        writer.append_data(image)

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
with plt.xkcd():
  plt.barh(langs,students)
  plt.show()
