# %% [markdown]
# <a href="https://colab.research.google.com/github/jcjimenezb123/ProgramacionPython/blob/master/Sipco_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-telegram-bot
# Out:
# Collecting python-telegram-bot
#   Downloading https://files.pythonhosted.org/packages/16/48/1673b175b878e1ddf6608814cfdc3a9b899cd1e13d4d00b37f2d6b5a0c45/python_telegram_bot-13.2-py3-none-any.whl (434kB)
#      |████████████████████████████████| 440kB 13.2MB/s
# Collecting cryptography
#   Downloading https://files.pythonhosted.org/packages/2f/61/6f4765822d1f3878c913755bd99212f1ab0b9fa808fc2197ace0790f4cdb/cryptography-3.4.5-cp36-abi3-manylinux2014_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 26.1MB/s
# Requirement already satisfied: pytz>=2018.6 in /usr/local/lib/python3.6/dist-packages (from python-telegram-bot) (2018.9)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.6/dist-packages (from python-telegram-bot) (5.1.1)
# Collecting APScheduler==3.6.3
#   Downloading https://files.pythonhosted.org/packages/f3/34/9ef20ed473c4fd2c3df54ef77a27ae3fc7500b16b192add4720cab8b2c09/APScheduler-3.6.3-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 6.3MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from python-telegram-bot) (2020.12.5)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.6/dist-packages (from cryptography->python-telegram-bot) (1.14.4)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from APScheduler==3.6.3->python-telegram-bot) (1.15.0)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.6/dist-packages (from APScheduler==3.6.3->python-telegram-bot) (1.5.1)
# Requirement already satisfied: setuptools>=0.7 in /usr/local/lib/python3.6/dist-packages (from APScheduler==3.6.3->python-telegram-bot) (53.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.12->cryptography->python-telegram-bot) (2.20)
# Installing collected packages: cryptography, APScheduler, python-telegram-bot
# Successfully installed APScheduler-3.6.3 cryptography-3.4.5 python-telegram-bot-13.2

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# This program is dedicated to the public domain under the CC0 license.
#
# THIS EXAMPLE HAS BEEN UPDATED TO WORK WITH THE BETA VERSION 12 OF PYTHON-TELEGRAM-BOT.
# If you're still using version 11.1.0, please see the examples at
# https://github.com/python-telegram-bot/python-telegram-bot/tree/v11.1.0/examples

"""
Simple Bot to reply to Telegram messages.

First, a few handler functions are defined. Then, those functions are passed to
the Dispatcher and registered at their respective places.
Then, the bot is started and runs until we press Ctrl-C on the command line.

Usage:
Basic Echobot example, repeats messages.
Press Ctrl-C on the command line or send a signal to the process to stop the
bot.
"""

import logging
import telegram
from telegram.ext import Updater, CommandHandler, MessageHandler, Filters
from os import popen 

# Enable logging
logging.basicConfig(format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
                    level=logging.INFO)

logger = logging.getLogger(__name__)


# Define a few command handlers. These usually take the two arguments bot and
# update. Error handlers also receive the raised TelegramError object in error.
def start(update, context):
    """Send a message when the command /start is issued."""

    chat_id = update.message.chat_id
    first_name = update.message.chat.first_name
    last_name = update.message.chat.last_name
    username = update.message.chat.username
    name = first_name+' '+last_name

    ########### con el username recuperar el area de la base de datos
    area = 'ROPA'

    if username=='jjimenezPS':
      area='CALZADO'
    ##############

    update.message.reply_text('Hola! '+name+' ['+username+']')
    update.message.reply_text('Area '+area)
                              
def ayuda(update, context):
    """Send a message when the command /help is issued."""
    update.message.reply_text('mis comandos son:\n\n/pendientes\n/autorizar #\n/rechazar #\n/consultar #\n/sumar # #\n/temporada XXXX')

def pdf(update,context):
    chat_id = update.message.chat_id
    bot=telegram.Bot(token='1603670932:AAElv74jFK7YP1_xhoqjfmlgDlBGf4XqCpo')

    for valor in context.args:
       with open('solicitud_'+valor+'.pdf','rb') as documento:
         bot.sendDocument(chat_id=chat_id,document=documento,caption='Solicitud '+str(valor))

def echo(update, context):
    """Echo the user message."""
    update.message.reply_text(update.message.text)


def error(update, context):
    """Log Errors caused by Updates."""
    logger.warning('Update "%s" caused error "%s"', update, context.error)

def conversa(update, context):
    if(update.message.text.upper().find("MANZANAS VERDES") >= 0):
        update.message.reply_text("Prefiero comer pizza")
    if(update.message.text.upper().find("SIPCO") >= 0):
        update.message.reply_text("He escuchado que SIPCO es uno de los mejores sistemas en Price Shoes")
    if(update.message.text.upper().find("PRICE SHOES") >= 0):
        update.message.reply_text("Price Shoes es la bodega de ropa y calzado mas grande de Latino America")
    if(update.message.text.upper().find("QUIEN ERES") >= 0 or 
       update.message.text.upper().find("HOLA") >= 0 or
       update.message.text.upper().find("BUENOS DIAS") >= 0 or
       update.message.text.upper().find("BUENAS TARDES") >= 0 or
       update.message.text.upper().find("QUIÉN ERES") >= 0):
        update.message.reply_text("Hola, yo soy SIPCO BOT 🤓, fui creado para ayudate en tu operación")
        update.message.reply_text("Escribe /ayuda para conocer mis habilidades")
    if(update.message.text.upper().find("PUEDES HACER") >= 0):
        update.message.reply_text("Para conocer lo que puedo hacer solo escribe /ayuda y te muestro mis habilidades")
    if(update.message.text.upper().find("TACOS") >= 0):
        update.message.reply_text("Te recomiendo los tacos vallejo, son buenos !!\no si prefieres de canasta los de don chucho en el centro son los mejores.")
    update.message.reply_text('👍')
    
def pendientes(update, context):
    username = update.message.chat.username
    first_name = update.message.chat.first_name
    last_name = update.message.chat.last_name
    username = update.message.chat.username
    name = first_name+' '+last_name

    ############## recuperar los pendientes del username enviado
    area = "ROPA"
    if(area=="ROPA"):
        update.message.reply_text("tus pendientes de "+area+" son 1234,5678")
    elif(area=="CALZADO"):
        update.message.reply_text("tus pendientes de "+area+" son 98765,4321")
    elif(area.upper().find("OL") > 0):
        update.message.reply_text("tus pendientes de "+area+" son 98765,4321")
    else:
      update.message.reply_text("El area "+area+" no esta considerada en el proceso")
    ####################

def autorizar(update, context):
    username = update.message.chat.username
    first_name = update.message.chat.first_name
    last_name = update.message.chat.last_name
    username = update.message.chat.username
    name = first_name+' '+last_name
    
    for valor in context.args:
      ############ autorizar cada solicitud de acuerdo al username enviado
      update.message.reply_text("la solicitud "+valor+" fue autorizada por "+name)

def rechazar(update, context):
    username = update.message.chat.username
    first_name = update.message.chat.first_name
    last_name = update.message.chat.last_name
    username = update.message.chat.username
    name = first_name+' '+last_name

    numero = context.args[0]
    motivo = " ".join(context.args[1:])
    update.message.reply_text("la solicitud "+numero+" fue rechazada por "+motivo)


def consultar(update, context):
    username = update.message.chat.username
    first_name = update.message.chat.first_name
    last_name = update.message.chat.last_name
    username = update.message.chat.username
    name = first_name+' '+last_name

    for valor in context.args:
      ############ consultar cada solicitud de acuerdo al username enviado
      update.message.reply_text("Detalle de la solicitud "+valor+"\n\n")

def temporada(update, context):
    username = update.message.chat.username
    first_name = update.message.chat.first_name
    last_name = update.message.chat.last_name
    username = update.message.chat.username
    name = first_name+' '+last_name
    ############ consultar la temporada de acuerdo al username enviado
    update.message.reply_text("Resumen de la temporada "+context.args[0]+"\n\nPresupuesto\nCompra\nPagos\nBalance")

def sumar(update,context):
    try:
      suma=0
      for valor in context.args:
        numero = float(valor)
        suma = suma + numero

      update.message.reply_text("La suma es "+str(suma))

    except (ValueError):
        update.message.reply_text("por favor utilice dos numeros")

def downloader(update, context):
    try:
      context.bot.get_file(update.message.document).download()

      # writing to a custom file
      with open("file.pdf", 'wb') as f:
          context.bot.get_file(update.message.document).download(out=f)
      update.message.reply_text("Documento recibido")
    except (ValueError):
        update.message.reply_text("Error al recibir el archivo")

def main():
    """Start the bot."""
    # Create the Updater and pass it your bot's token.
    # Make sure to set use_context=True to use the new context based callbacks
    # Post version 12 this will no longer be necessary

    updater = Updater("1603670932:AAElv74jFK7YP1_xhoqjfmlgDlBGf4XqCpo", use_context=True)

    # Get the dispatcher to register handlers
    dp = updater.dispatcher

    # on different commands - answer in Telegram
    dp.add_handler(CommandHandler("start", start))
    dp.add_handler(CommandHandler("ayuda", ayuda))
    dp.add_handler(CommandHandler("sumar", sumar))
    dp.add_handler(CommandHandler("pendientes", pendientes))
    dp.add_handler(CommandHandler("autorizar", autorizar))
    dp.add_handler(CommandHandler("rechazar", rechazar))
    dp.add_handler(CommandHandler("consultar", consultar))
    dp.add_handler(CommandHandler("temporada", temporada))
    dp.add_handler(MessageHandler(Filters.document, downloader))
    dp.add_handler(CommandHandler("pdf",pdf))

    # on noncommand i.e message - echo the message on Telegram
    dp.add_handler(MessageHandler(Filters.text, conversa))

    # log all errors
    dp.add_error_handler(error)

    # Start the Bot
    updater.start_polling()

    # Run the bot until you press Ctrl-C or the process receives SIGINT,
    # SIGTERM or SIGABRT. This should be used most of the time, since
    # start_polling() is non-blocking and will stop the bot gracefully.
    updater.idle()


if __name__ == '__main__':
    main()
# Out:
# 2021-02-15 23:37:17,812 - apscheduler.scheduler - INFO - Scheduler started
# 2021-02-15 23:40:17,503 - telegram.ext.updater - INFO - Received signal 2 (SIGINT), stopping...
# 2021-02-15 23:40:17,505 - apscheduler.scheduler - INFO - Scheduler has been shut down
