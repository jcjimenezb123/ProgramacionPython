# %% [markdown]
# <a href="https://colab.research.google.com/github/jcjimenezb123/ProgramacionPython/blob/master/TeoriaRedes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# The following line initializes an empty directed graph objects
G1=nx.DiGraph()

# %%
G1.add_node(1)
G1.add_node(2)
G1.add_node(3)
G1.add_node(4)
G1.add_node(5)
G1.add_node(6)
G1.nodes()
# Out:
# NodeView((1, 2, 3, 4, 5, 6))

# %%
G1.add_edge(1, 2, weight = 2.0)
G1.add_edge(1, 3, weight = 4.0)
G1.add_edge(2, 3, weight = 1.0)
G1.add_edge(2, 4, weight = 4.0)
G1.add_edge(2, 5, weight = 2.0)
G1.add_edge(3, 5, weight = 3.0)
G1.add_edge(4, 6, weight = 2.0)
G1.add_edge(5, 4, weight = 3.0)
G1.add_edge(5, 6, weight = 2.0)
G1.edges()
# Out:
# OutEdgeView([(1, 2), (1, 3), (2, 3), (2, 4), (2, 5), (3, 5), (4, 6), (5, 4), (5, 6)])

# %%
list_nodes = [1, 2, 3, 4, 5, 6]
G1.add_nodes_from(list_nodes)
G1.nodes()
# Out:
# NodeView((1, 2, 3, 4, 5, 6))

# %%
list_arcs = [(1,2,2.0) , (1,3,4.0) , (2,3,1.0) , (2,4,4.0) , (2,5,2.0) , (3,5,3.0) , (4,6,2.0) , (5,4,3.0) , (5,6,2.0)]
G1.add_weighted_edges_from(list_arcs)
G1.edges()
# Out:
# OutEdgeView([(1, 2), (1, 3), (2, 3), (2, 4), (2, 5), (3, 5), (4, 6), (5, 4), (5, 6)])

# %%
nx.draw(G1,with_labels=1,node_color='c',
        edge_color=['salmon','limegreen','darkviolet','gold','pink','dodgerblue','chocolate','orange','gray'], 
        node_size=1000)

# %%
sp = nx.dijkstra_path(G1,source = 1, target = 6)
print(sp)
# Out:
# [1, 2, 5, 6]

# %%
print(nx.shortest_path(G1,source = 1, target = 6))
# Out:
# [1, 2, 4, 6]

# %%
# First we import the matplotlib python plotting package
import matplotlib.pyplot as plt
# We then set the coordinates of each node
G1.nodes[1]['pos'] = (0,0)
G1.nodes[2]['pos'] = (1,1)
G1.nodes[3]['pos'] = (1,-1)
G1.nodes[4]['pos'] = (2,1)
G1.nodes[5]['pos'] = (2,-1)
G1.nodes[6]['pos'] = (3,0)
# The positions of each node are stored in a dictionary
node_pos=nx.get_node_attributes(G1,'pos')
# The edge weights of each arcs are stored in a dictionary
arc_weight=nx.get_edge_attributes(G1,'weight')
# Create a list of arcs in the shortest path using the zip command and store it in red edges
red_edges = list(zip(sp,sp[1:]))
# If the node is in the shortest path, set it to red, else set it to white color
node_col = ['cyan' if not node in sp else 'red' for node in G1.nodes()]
# If the edge is in the shortest path set it to red, else set it to white color
edge_col = ['black' if not edge in red_edges else 'red' for edge in G1.edges()]
# Draw the nodes
nx.draw_networkx(G1, node_pos,node_color= node_col, node_size=450)
# Draw the node labels
nx.draw_networkx_labels(G1, node_pos)
# Draw the edges
nx.draw_networkx_edges(G1, node_pos,edge_color= edge_col)
# Draw the edge labels
nx.draw_networkx_edge_labels(G1, node_pos, edge_labels=arc_weight)
# Remove the axis
plt.axis('off')
# Show the plot
plt.show()

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/jcjimenezb123/ProgramacionPython/master/metro.csv')
df.head()
# Out:
#                     Desde                   Hasta  Distancia Linea Color
# 0               Pantitlán                Zaragoza       1320     1  pink
# 1                Zaragoza            Gómez Farías        762     1  pink
# 2            Gómez Farías  Boulevard Puerto Aéreo        611     1  pink
# 3  Boulevard Puerto Aéreo                Balbuena        595     1  pink
# 4                Balbuena               Moctezuma        703     1  pink

# %%
G=nx.from_pandas_edgelist(df, 'Desde', 'Hasta', ['Distancia','Color','Linea'])
G.nodes()
# Out:
# NodeView(('Pantitlán', 'Zaragoza', 'Gómez Farías', 'Boulevard Puerto Aéreo', 'Balbuena', 'Moctezuma', 'San Lázaro', 'Candelaria', 'Merced', 'Pino Suárez', 'Isabel la Católica', 'Salto del Agua', 'Balderas', 'Cuauhtémoc', 'Insurgentes', 'Sevilla', 'Chapultepec', 'Juanacatlán', 'Tacubaya', 'Observatorio', 'Cuatro Caminos', 'Panteones', 'Tacuba', 'Cuitláhuac', 'Popotla', 'Colegio Militar', 'Normal', 'San Cosme', 'Revolución', 'Hidalgo', 'Bellas Artes', 'Allende', 'Zócalo', 'San Antonio Abad', 'Chabacano', 'Viaducto', 'Xola', 'Villa de Cortés', 'Nativitas', 'Portales', 'Ermita', 'General Anaya', 'Tasqueña', 'Indios Verdes', 'Deportivo 18 de Marzo', 'Potrero', 'La Raza', 'Tlatelolco', 'Guerrero', 'Juárez', 'Niños Héroes', 'Hospital General', 'Centro Médico', 'Etiopía/Plaza de la Transparencia', 'Eugenia', 'División del norte', 'División del Norte', 'Zapata', 'Coyoacán', 'Viveros/Derechos Humanos', 'Miguel Ángel de Quevedo', 'Copilco', 'Universidad', 'Santa Anita', 'Jamaica', 'Fray Servand
# ...

# %%
G.edges()
# Out:
# EdgeView([('Pantitlán', 'Zaragoza'), ('Pantitlán', 'Hangares'), ('Pantitlán', 'Puebla'), ('Pantitlán', 'Agrícola Oriental'), ('Zaragoza', 'Gómez Farías'), ('Gómez Farías', 'Boulevard Puerto Aéreo'), ('Boulevard Puerto Aéreo', 'Balbuena'), ('Balbuena', 'Moctezuma'), ('Moctezuma', 'San Lázaro'), ('San Lázaro', 'Candelaria'), ('San Lázaro', 'Ricardo Flores Magón'), ('San Lázaro', 'Morelos'), ('Candelaria', 'Merced'), ('Candelaria', 'Fray Servando'), ('Candelaria', 'Morelos'), ('Merced', 'Pino Suárez'), ('Pino Suárez', 'Isabel la Católica'), ('Pino Suárez', 'Zócalo'), ('Pino Suárez', 'San Antonio Abad'), ('Isabel la Católica', 'Salto del Agua'), ('Salto del Agua', 'Balderas'), ('Salto del Agua', 'San Juan de Letrán'), ('Salto del Agua', 'Doctores'), ('Balderas', 'Cuauhtémoc'), ('Balderas', 'Juárez'), ('Balderas', 'Niños Héroes'), ('Cuauhtémoc', 'Insurgentes'), ('Insurgentes', 'Sevilla'), ('Sevilla', 'Chapultepec'), ('Chapultepec', 'Juanacatlán'), ('Juanacatlán', 'Tacubaya'), ('Tacubaya',
# ...

# %%
G.order()
# Out:
# 164

# %%
G['Copilco']['Universidad']['Distancia']
# Out:
# 1306

# %%
G['Copilco']['Universidad']['Color']
# Out:
# 'olive'

# %%
G['Copilco']['Universidad']['Linea']
# Out:
# '3'

# %%
[n for n in G.nodes() if G.degree(n)>2]
# Out:
# ['Pantitlán',
#  'San Lázaro',
#  'Candelaria',
#  'Pino Suárez',
#  'Salto del Agua',
#  'Balderas',
#  'Tacubaya',
#  'Tacuba',
#  'Hidalgo',
#  'Bellas Artes',
#  'Chabacano',
#  'Ermita',
#  'Deportivo 18 de Marzo',
#  'La Raza',
#  'Guerrero',
#  'Centro Médico',
#  'Zapata',
#  'Santa Anita',
#  'Jamaica',
#  'Morelos',
#  'Consulado',
#  'Instituto del Petróleo',
#  'Oceanía',
#  'Mixcoac',
#  'Garibaldi',
#  'Atlalilco']

# %%
nx.draw(G,with_labels=0,node_color='c')

# %%
nx.draw_circular(G,with_labels=0,node_color='c')

# %%
color_linea=[G[origen][destino]['Color'] for (origen,destino) in G.edges()]
nx.draw_spring(G,with_labels=0,
               edge_color=color_linea,node_size=50)

# %%
ruta = nx.dijkstra_path(G,source = 'Tláhuac', target = 'Martín Carrera')
print(ruta)
# Out:
# ['Tláhuac', 'Tlaltenco', 'Zapotitlán', 'Nopalera', 'Olivos', 'Tezonco', 'Periférico Oriente', 'Calle 11', 'Lomas Estrella', 'San Andrés Tomatlán', 'Culhuacán', 'Atlalilco', 'Escuadrón 201', 'Aculco', 'Apatlaco', 'Iztacalco', 'Coyuya', 'Santa Anita', 'Jamaica', 'Fray Servando', 'Candelaria', 'Morelos', 'Canal del Norte', 'Consulado', 'Bondojito', 'Talismán', 'Martín Carrera']

# %%
r=G.subgraph(ruta)

color=[G[o][d]['Color'] for (o,d) in r.edges()]
linea=[(o,d,G[o][d]['Linea']) for (o,d) in r.edges()]
linea
# Out:
# [('Tlaltenco', 'Tláhuac', '12'),
#  ('Tlaltenco', 'Zapotitlán', '12'),
#  ('Talismán', 'Bondojito', '4'),
#  ('Talismán', 'Martín Carrera', '4'),
#  ('Canal del Norte', 'Morelos', '4'),
#  ('Canal del Norte', 'Consulado', '4'),
#  ('Olivos', 'Nopalera', '12'),
#  ('Olivos', 'Tezonco', '12'),
#  ('Fray Servando', 'Jamaica', '4'),
#  ('Fray Servando', 'Candelaria', '4'),
#  ('Iztacalco', 'Coyuya', '8'),
#  ('Iztacalco', 'Apatlaco', '8'),
#  ('Atlalilco', 'Escuadrón 201', '8'),
#  ('Atlalilco', 'Culhuacán', '12'),
#  ('Morelos', 'Candelaria', '4'),
#  ('Apatlaco', 'Aculco', '8'),
#  ('Culhuacán', 'San Andrés Tomatlán', '12'),
#  ('Periférico Oriente', 'Tezonco', '12'),
#  ('Periférico Oriente', 'Calle 11', '12'),
#  ('Escuadrón 201', 'Aculco', '8'),
#  ('Bondojito', 'Consulado', '4'),
#  ('Lomas Estrella', 'Calle 11', '12'),
#  ('Lomas Estrella', 'San Andrés Tomatlán', '12'),
#  ('Nopalera', 'Zapotitlán', '12'),
#  ('Coyuya', 'Santa Anita', '8'),
#  ('Santa Anita', 'Jamaica', '4')]

# %%
pos = nx.spring_layout(r)

nx.draw(r,pos,with_labels=1,
        edge_color=color,
        font_color="salmon", 
        node_shape="s",
        node_size=20, alpha=0.6, linewidths=10)

edge_labels = nx.get_edge_attributes(r, 'Linea')

nx.draw_networkx_edge_labels(r, pos, edge_labels=edge_labels)

plt.show()

# %%
d=[G[o][d]['Distancia'] for (o,d) in r.edges()]
ds=[(o,d,G[o][d]['Distancia']) for (o,d) in r.edges()]
print('Vector de distancias %s'%d)
print('Vector de distancias %s'%ds)
print('Distancia recorrida %s m' %sum(d))
# Out:
# Vector de distancias [1298, 1115, 959, 1129, 910, 884, 1360, 490, 1033, 633, 993, 910, 1738, 1671, 1062, 534, 990, 1545, 1111, 789, 645, 906, 1060, 1276, 968, 758]
# ...

# %%
ruta = nx.astar_path(G,source = 'Universidad', target = 'Polanco')
print(ruta)
# Out:
# ['Universidad', 'Copilco', 'Miguel Ángel de Quevedo', 'Viveros/Derechos Humanos', 'Coyoacán', 'Zapata', 'Hospital 20 de Noviembre', 'Insurgentes Sur', 'Mixcoac', 'San Antonio', 'San Pedro de los Pinos', 'Tacubaya', 'Constituyentes', 'Auditorio', 'Polanco']
